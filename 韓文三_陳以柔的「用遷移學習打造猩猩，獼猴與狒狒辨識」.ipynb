# %% [markdown]
# <a href="https://colab.research.google.com/github/Atircharlotte/1102--math_sw_application/blob/main/%E9%9F%93%E6%96%87%E4%B8%89_%E9%99%B3%E4%BB%A5%E6%9F%94%E7%9A%84%E3%80%8C%E7%94%A8%E9%81%B7%E7%A7%BB%E5%AD%B8%E7%BF%92%E6%89%93%E9%80%A0%E7%8C%A9%E7%8C%A9%EF%BC%8C%E7%8D%BC%E7%8C%B4%E8%88%87%E7%8B%92%E7%8B%92%E8%BE%A8%E8%AD%98%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 挑戰利用5張猩猩,5張獼猴和和5張狒狒的照片，來打造一個會分辨猩猩,獼猴,狒狒的神經網路！

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# # 1.讀入猩猩、獼猴、狒狒的資料圖檔

# %% [markdown]
# 把在雲端裡的猩猩,獼猴和狒狒的照片讀進來

# %%
# !wget --no-check-certificate \
https://drive.google.com/file/d/114XCMaLFYq4fdWBdPPGoCpRbJ_VXLNIz/view?usp=sharing -O monkeys.zip
# Out:
# --2022-04-26 06:26:04--  https://drive.google.com/file/d/114XCMaLFYq4fdWBdPPGoCpRbJ_VXLNIz/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 64.233.189.113, 64.233.189.102, 64.233.189.101, ...
# Connecting to drive.google.com (drive.google.com)|64.233.189.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘monkeys.zip’
#
# monkeys.zip             [ <=>                ]  64.62K  --.-KB/s    in 0.1s
#
# 2022-04-26 06:26:05 (475 KB/s) - ‘monkeys.zip’ saved [66169]

# %%
import os
import zipfile

local_zip = '/content/monkeys.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content') #解壓縮
zip_ref.close()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-16-55249cc5bced> in <module>()
#       3
#       4 local_zip = '/content/monkeys.zip'
# ----> 5 zip_ref = zipfile.ZipFile(local_zip, 'r')
#       6 zip_ref.extractall('/content') #解壓縮
#       7 zip_ref.close()
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# -> 1258                 self._RealGetContents()
#    1259             elif mode in ('w', 'x'):
#    1260                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1323             raise BadZipFile("File is not a zip file")
#    1324         if not endrec:
# -> 1325             raise BadZipFile("File is not a zip file")
#    1326         if self.debug > 1:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 把猩猩和獼猴的照片轉為訓練資料

# %%
base_dir = "/content/"

# %%
monkeys_folders = ["macaque", "gorilla", "baboon"]

# %%
thedir = base_dir + monkeys_folders[0]
os.listdir(thedir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-2e22a38bbc02> in <module>()
#       1 thedir = base_dir + monkeys_folders[0]
# ----> 2 os.listdir(thedir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/macaque'
